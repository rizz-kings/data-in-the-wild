# %%
import tmdbsimple as tmdb

tmdb.API_KEY = '181cade2ad3f7162ef06b83dd94c0983'

# %%
mcu_list = tmdb.Discover().movie(with_keywords="180547", page=4)

mcu_list
# Out:
# {'page': 4,
#  'results': [{'adult': False,
#    'backdrop_path': '/cU0NFIVj11wo2ERNsb6pBeefqgV.jpg',
#    'genre_ids': [35, 878],
#    'id': 413279,
#    'original_language': 'en',
#    'original_title': 'Team Thor',
#    'overview': 'Discover what Thor was up to during the events of Captain America: Civil War.',
#    'popularity': 10.928,
#    'poster_path': '/jVSmX89BvsQV2z3wh2IVYVNVw1a.jpg',
#    'release_date': '2016-08-28',
#    'title': 'Team Thor',
#    'video': False,
#    'vote_average': 7.3,
#    'vote_count': 492},
#   {'adult': False,
#    'backdrop_path': '/e6RHrRaG8t5o2REYMfYkvhoamw2.jpg',
#    'genre_ids': [28, 35, 14],
#    'id': 253980,
#    'original_language': 'en',
#    'original_title': 'Marvel One-Shot: All Hail the King',
#    'overview': 'A documentary filmmaker interviews the now-famous Trevor Slattery from behind bars.',
#    'popularity': 11.251,
#    'poster_path': '/ozXvopXv1TiOTls8zb09dBmu9dt.jpg',
#    'release_date': '2014-02-04',
#    'title': 'Marvel One-Shot: All Hail the King',
#    'video': False,
#    'vote_average': 6.8,
#    'vote_count': 466},
#   {'adult': False,
#    'backdrop_path': '/oBIn5pHlbmZgr5b8D6WL10rsgO5.jpg',
#    'genre_ids': [878, 35, 14],
#    'id': 441829,
#    'original_language': 'en',
#    'original_title': 'Team Thor: Part 2',
#    'overview': 'A continuation of the documentary spoof of what Thor and his roommate Darryl were up to during the events of "Captain America: Civil War". While Cap and Iron Man duke it out, Thor tries to pay Darryl his rent in Asgardian coins.',
#    'popularity': 9.628,
#    'poster_path': '/9Vt1OLu3BrKy1IQFK3QyzpR1LVm.jpg',
#    'release_date': '2017-02-14',
#    'title': 'Team Thor: Part 2',
#    'video': False,
#    'vote_average': 7,
#    'vote_count': 289},
#   {'adult': False,
#    'backdrop_path': '/709oX5ro1SON6OkaVnA8MOx1WSK.jpg',
#    'genre_ids': [99],
#    'id': 979160,
#    'original_language': 'en',
#    'original_title': "A Fan's Guide to Ms. Marvel",
#    'overview': 'A documentary short that gives you an exclusive look behind the groundbreaking original series, "Ms. Marvel", from its comic book origins to its development and production as Marvel Studios’ next hit series on Disney+. It features interviews with its award winning filmmaking team and the show’s captivating star, newcomer Iman Vellani.',
#    'popularity': 5.309,
#    'poster_path': '/aolMYjs6QWonQFlnRGvU3o5zeQH.jpg',
#    'release_date': '2022-06-01',
#    'title': "A Fan's Guide to Ms. Marvel",
#    'video': False,
#    'vote_average': 7.1,
#    'vote_count': 67},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [28, 878],
#    'id': 969681,
#    'original_language': 'en',
#    'original_title': 'Spider-Man 4',
#    'overview': 'The next installment of the MCU Spider-Man franchise: a sequel to "Spider-Man: No Way Home" and the first in a possible new trilogy. Plot unknown.',
#    'popularity': 8.242,
#    'poster_path': None,
#    'title': 'Spider-Man 4',
#    'video': False,
#    'vote_average': 0,
#    'vote_count': 0},
#   {'adult': False,
#    'backdrop_path': '/7unMknm8DM2BXQsKL0jhbgfs43h.jpg',
#    'genre_ids': [99],
#    'id': 1127361,
#    'original_language': 'en',
#    'original_title': 'Marvel Studios Assembled: The Making of Ant-Man and the Wasp: Quantumania',
#    'overview': 'Join cast and crew as they delve deep into the creation of "Ant-Man and The Wasp: Quantumania." Combining immersive behind-the-scenes footage with candid interviews, Assembled reveals how an incredible new world was brought to the screen.',
#    'popularity': 7.981,
#    'poster_path': '/xgfnWe9NFXT5o3QndRnU5ylkxyp.jpg',
#    'release_date': '2023-07-19',
#    'title': 'Marvel Studios Assembled: The Making of Ant-Man and the Wasp: Quantumania',
#    'video': False,
#    'vote_average': 6,
#    'vote_count': 12},
#   {'adult': False,
#    'backdrop_path': '/qG5A6fWoP5inQa16VadLDiB1mlb.jpg',
#    'genre_ids': [878, 28, 12],
#    'id': 758025,
#    'original_language': 'en',
#    'original_title': "Peter's To-Do List",
#    'overview': 'On the eve of his departure to Europe, Peter Parker tells Ned Leeds that he has several things to do before they leave.',
#    'popularity': 6.242,
#    'poster_path': '/2LoW0WMYHwhxXQr1wz6xCVRiX9.jpg',
#    'release_date': '2019-09-17',
#    'title': "Peter's To-Do List",
#    'video': False,
#    'vote_average': 6.8,
#    'vote_count': 60},
#   {'adult': False,
#    'backdrop_path': '/bZtu0UE0afN3jrkoUSJP8eO9yU.jpg',
#    'genre_ids': [35],
#    'id': 505945,
#    'original_language': 'en',
#    'original_title': 'Team Darryl',
#    'overview': 'Fresh off being unseated as the ruler of Sakaar, the Grandmaster makes his way to Earth to start a new life. It\'s been over a year since Thor left Australia and Darryl has been struggling to pay his rent. Now Darryl needs a new roommate to help make the monthly payments. Unfortunately for Darryl, the Grandmaster was the only one who answered Darryl\'s "Roommate Needed" ad and with no viable options, the Grandmaster moves in.',
#    'popularity': 6.504,
#    'poster_path': '/edroTAeTEM9ILyAnumA0ALxRSne.jpg',
#    'release_date': '2018-02-20',
#    'title': 'Team Darryl',
#    'video': False,
#    'vote_average': 6.2,
#    'vote_count': 128},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [99],
#    'id': 1192825,
#    'original_language': 'en',
#    'original_title': 'Marvel Studios Assembled: The Making of Loki: Season 2',
#    'overview': 'Through candid interviews with the creative minds behind the show, and exclusive on-set footage, discover how the talented team that powered "Loki: Season 2" raised the stakes for this latest MCU adventure. Witness imaginative costumes, elaborate environments, and far-out variants come to life, meet new allies and foes, and time-slip across the Multiverse.',
#    'popularity': 6.596,
#    'poster_path': None,
#    'release_date': '2023-11-29',
#    'title': 'Marvel Studios Assembled: The Making of Loki: Season 2',
#    'video': False,
#    'vote_average': 0,
#    'vote_count': 0},
#   {'adult': False,
#    'backdrop_path': '/qXOYUTJ5p5aINFGmyIWTGeZCNTc.jpg',
#    'genre_ids': [99],
#    'id': 1001912,
#    'original_language': 'en',
#    'original_title': 'Marvel Studios Assembled: The Making of Ms. Marvel',
#    'overview': 'Go behind-the-scenes every step of the way with immersive footage from the making of the series, along with insightful interviews on set from the cast and crew of Ms. Marvel as we watch Iman Vellani and her character, Kamala Khan, become the fan-favorite superhero right before our eyes.',
#    'popularity': 7.086,
#    'poster_path': '/6m0rG2bS90FOlUaxEq8ZPCTQMei.jpg',
#    'release_date': '2022-08-03',
#    'title': 'Marvel Studios Assembled: The Making of Ms. Marvel',
#    'video': False,
#    'vote_average': 7.2,
#    'vote_count': 27},
#   {'adult': False,
#    'backdrop_path': '/rLnv5QXUE3ITZTfrobsfXuAUtG.jpg',
#    'genre_ids': [99],
#    'id': 877188,
#    'original_language': 'en',
#    'original_title': "Marvel Studios' 2021 Disney+ Day Special",
#    'overview': 'Explore the Disney+ series of the MCU—past, present and future.',
#    'popularity': 5.05,
#    'poster_path': '/zh0B5DDP93e3zokktb5aHHfIh01.jpg',
#    'release_date': '2021-11-12',
#    'title': "Marvel Studios' 2021 Disney+ Day Special",
#    'video': False,
#    'vote_average': 6.7,
#    'vote_count': 24},
#   {'adult': False,
#    'backdrop_path': '/43NgWUj0Sr9AoM8Prv0QOWsL92k.jpg',
#    'genre_ids': [99],
#    'id': 647375,
#    'original_language': 'en',
#    'original_title': 'Marvel Studios: Expanding the Universe',
#    'overview': "An exciting look into the future of Marvel Studios' films and upcoming Disney+ series.",
#    'popularity': 4.631,
#    'poster_path': '/dU7qXzttvOUvSlwwpEFQDsLnThK.jpg',
#    'release_date': '2019-11-12',
#    'title': 'Marvel Studios: Expanding the Universe',
#    'video': False,
#    'vote_average': 5.7,
#    'vote_count': 22},
#   {'adult': False,
#    'backdrop_path': '/h7BU4fdLjF8ly8NF8mJ4hAQOLKU.jpg',
#    'genre_ids': [878, 28],
#    'id': 1030022,
#    'original_language': 'en',
#    'original_title': 'Armor Wars',
#    'overview': "James Rhodes aka War Machine faces the consequences of Tony Stark's worst fear coming true: what happens when his tech falls into the wrong hands?",
#    'popularity': 2.444,
#    'poster_path': '/vDbzi8eM710THVCwjfqVU8a5E3g.jpg',
#    'title': 'Armor Wars',
#    'video': False,
#    'vote_average': 0,
#    'vote_count': 0},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [],
#    'id': 1072946,
#    'original_language': 'en',
#    'original_title': 'Doctor Strange 3',
#    'overview': 'Rumored sequel to Doctor Strange in the Multiverse of Madness.',
#    'popularity': 1.294,
#    'poster_path': None,
#    'release_date': '',
#    'title': 'Doctor Strange 3',
#    'video': False,
#    'vote_average': 0,
#    'vote_count': 0},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [878, 14],
#    'id': 1196551,
#    'original_language': 'en',
#    'original_title': 'Thor 5',
#    'overview': 'Rumored fifth installment in Marvel Studios’ Thor franchise.',
#    'popularity': 1.254,
#    'poster_path': None,
#    'release_date': '',
#    'title': 'Thor 5',
#    'video': False,
#    'vote_average': 0,
#    'vote_count': 0},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [],
#    'id': 1037199,
#    'original_language': 'en',
#    'original_title': 'Black Panther 3',
#    'overview': 'Rumored third installment in Marvel Studios’ Black Panther franchise.',
#    'popularity': 0.673,
#    'poster_path': None,
#    'release_date': '',
#    'title': 'Black Panther 3',
#    'video': False,
#    'vote_average': 0,
#    'vote_count': 0},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [10770],
#    'id': 1101411,
#    'original_language': 'en',
#    'original_title': 'Untitled Sentry Special',
#    'overview': 'A Marvel Studios Special Presentation adapting the Marvel Comics superhero Sentry.',
#    'popularity': 0.6,
#    'poster_path': None,
#    'release_date': '',
#    'title': 'Untitled Sentry Special',
#    'video': False,
#    'vote_average': 0,
#    'vote_count': 0}],
#  'total_pages': 4,
#  'total_results': 77}

# %%
from datetime import datetime
from time import strftime

today = datetime.now().strftime("%Y-%m-%d")

total_pages = tmdb.Discover().movie(with_keywords=['9715'], without_keywords='263548')['total_pages']

movie_list = []
movie_ids = []

for page in range(1, total_pages+1):
    current_page = tmdb.Discover().movie(with_keywords=['9715'], without_keywords='263548', page=page)
    for movie in current_page['results']:
        if "release_date" in movie and (movie["release_date"] < today and movie['release_date'] != ''):
            movie_name = movie['title']
            print(movie_name)
            movie_list.append(movie_name)
            movie_ids.append(movie['id'])
# Out:
# Blue Beetle
# Spider-Man: Across the Spider-Verse
# The Flash
# Justice League: Warworld
# Guardians of the Galaxy Vol. 3
# Teenage Mutant Ninja Turtles: Mutant Mayhem
# Miraculous: Ladybug & Cat Noir, The Movie
# Spider-Man: No Way Home
# Miraculous World: Paris, Tales of Shadybug and Claw Noir
# Ant-Man and the Wasp: Quantumania
# Knights of the Zodiac
# Avengers: Infinity War
# Shazam! Fury of the Gods
# Justice League x RWBY: Super Heroes & Huntsmen, Part Two
# Scooby-Doo! And Krypto, Too!
# The Batman
# Black Panther: Wakanda Forever
# Black Adam
# Venom: Let There Be Carnage
# The Avengers
# Avengers: Endgame
# Shang-Chi and the Legend of the Ten Rings
# Doctor Strange in the Multiverse of Madness
# Spider-Man: Into the Spider-Verse
# Shadow Master
# Thor: Love and Thunder
# Shin Kamen Rider
# Zack Snyder's Justice League
# The Suicide Squad
# Bloodshot
# Spider-Man
# Star Wars
# The Dark Knight
# Big Hero 6
# Venom
# Eternals
# The Amazing Spider-Man
# The Amazing Spider-Man 2
# Spider-Man 3
# Avengers: Age of Ultron
# Deadpool
# Spider-Man: Homecoming
# Iron Man 2
# Thor: Ragnarok
# Teenage Mutant Ninja Turtles
# Spider-Man: Far From Home
# Iron Man
# Deadpool 2
# Justice League
# Captain America: Civil War
# X-Men: Apocalypse
# Iron Man 3
# Captain Marvel
# Wonder Woman
# Guardians of the Galaxy Vol. 2
# The Dark Knight Rises
# The Incredibles
# Batman v Superman: Dawn of Justice
# Samaritan
# DC League of Super-Pets
# Aquaman
# Logan
# Dragon Ball Z: Broly – The Legendary Super Saiyan
# Birds of Prey (and the Fantabulous Emancipation of One Harley Quinn)
# Thor
# Incredibles 2
# Men in Black
# Suicide Squad
# Doctor Strange
# Batman Begins
# Thor: The Dark World
# Black Panther
# The Incredible Hulk
# Constantine
# Ant-Man
# Wonder Woman 1984
# My Hero Academia: World Heroes' Mission
# Glass
# Megamind
# The Mask
# Miraculous World: New York, United HeroeZ
# Blade
# Batman
# Ghost Rider: Spirit of Vengeance
# Alita: Battle Angel
# Shazam!
# Ghost Rider
# Miraculous World: Shanghai – The Legend of Ladydragon
# Man of Steel
# Men in Black II
# Chicken Little
# Deathstroke: Knights & Dragons - The Movie
# The Guardians of the Galaxy Holiday Special
# Captain America: The First Avenger
# Iron Man: Rise of Technovore
# Batman: The Doom That Came to Gotham
# Ant-Man and the Wasp
# Superman
# Hancock
# Hulk
# Birdman or (The Unexpected Virtue of Ignorance)
# Fuuto Presents: Kamen Rider W Special Event Supported by Windscale
# Bagboy!
# Hell Hath No Fury
# Fanthomas
# Thunderbolts and Lightning Strikes
# LEGO DC Super Hero Girls: Galactic Wonder
# Confessions of a Superhero
# The Amazing Compulsion
# O Judoka
# The Last Sunset
# Ultraman Connection Presents: Tamashii Nations Special Streaming featuring Ultraman Trigger
# MacCumhaill
# The Paper-Man
# TeraStorm
# Henshin! Henshin! Arashi and Rider
# Juken Sentai Gekiranger: Gyun-Gyun! Fist Sage Great Athletic Meet
# Hyakujuu Sentai Gaoranger Super Video: Showdown! Gaoranger vs. Gao Silver
# Engine Sentai Go-Onger Special DVD: It's a Seminar! Everyone GO-ON!!
# Bakuryuu Sentai Abaranger Super Video: All Bakuryuu Roaring Laughter Battle
# The Case of the Cosmic Comic
# Check YES!
# Spider Transgender Person
# Heroes Unite! Yatsurugi × Trio × Ninja Reppu
# 6 ULTRA BROTHERS THE LIVE in Hakuhinkan Theater Featuring Ultraman Vol. 2
# A Knight in Bludhaven
# Faceless
# Heroine Cruelty Story XVI
# Heroine Cruelty Story XIV
# Static Shock
# Thong Girl 3: Revenge of the Dark Widow
# Captain Green
# 30 Second Initiative (Short)
# 77 Group's Secret
# Kamen Rider Ghost: Final Stage
# Kamen Rider Zi-O: Final Stage
# Capitán Escudo
# Kamen Rider Decade: Protect! The World of Televikun
# KEN The Super Hero
# Japan Local Heroes Great Battle
# A Very Impossible Christmas
# The Clam
# SideKicked
# Villain Initiation
# Sign Gene
# Being Batman
# Action Man
# The Legends Behind the Comic Books
# The Bad Samaritan Must Die!
# U.S. Catman 2: Boxer Blow
# Thong Girl 4: The Body Electric
# Rat-Man
# Into Pieces
# Southern Superhero Showdown
# Wondrous Woman
# Tokumei Sentai Go-Busters vs. Kaizoku Sentai Gokaiger: The Movie
# U.S. Catman: Lethal Track
# Super Noypi
# Superman: The Lost Episodes
# 仮面ライダージュ〇ガＶＳ仮面ライダーオル〇カ

# %%
print(len(movie_list))
# Out:
# 834

# %%
movie_series = {
    "movie_name": [],
    "imdb_id": [],
    "cast": [],
    "direction": [],
    "production_companies": [],
    "movie_budget": [],
    "movie_revenue": []
    
}
for id in movie_ids:
    current_movie = tmdb.Movies(id)
    current_movie.info()
    movie_series["movie_name"].append(current_movie.title)
    movie_series["imdb_id"].append(current_movie.imdb_id)
    movie_series["movie_budget"].append(current_movie.budget)
    movie_series["movie_revenue"].append(current_movie.revenue)
    movie_cast = {}
    directors = []
    production_companies = []
    for cast in current_movie.credits()["cast"]:
        if 'character' in cast and cast["popularity"] > 5:
            movie_cast[cast["name"]] = cast["character"]
    for crew in current_movie.credits()["crew"]:
        if crew['job'] == "Director":
            directors.append(crew["name"])
    for company in current_movie.production_companies:
        production_companies.append(company["name"])
        
    movie_series["cast"].append(movie_cast)
    movie_series["direction"].append(directors)
    movie_series["production_companies"].append(production_companies)

# %%
len(movie_series["direction"])
# Out:
# 834

# %%
import pandas as pd



df = pd.DataFrame(movie_series)

df = df[df["movie_budget"] != 0]
df = df[df["movie_revenue"] != 0]
df = df[df["cast"] != {}]

df
# Out:
#                                       movie_name    imdb_id  \
# 0                                    Blue Beetle  tt9362930
# 1            Spider-Man: Across the Spider-Verse  tt9362722
# 2                                      The Flash  tt0439572
# 4                 Guardians of the Galaxy Vol. 3  tt6791350
# 5    Teenage Mutant Ninja Turtles: Mutant Mayhem  tt8589698
# ..                                           ...        ...
# 382                     X-Men Origins: Wolverine  tt0458525
# 539                           X-Men: First Class  tt1270798
# 577                                        X-Men  tt0120903
# 610                                           X2  tt0290334
# 713                                     3 Braves  tt4306116
#
#                                                   cast  \
# 0    {'Xolo Mariduena': 'Jaime Reyes / Blue Beetle'...
# 1    {'Shameik Moore': 'Miles Morales / Spider-Man ...
# 2    {'Ezra Miller': 'Barry Allen / The Flash', 'Sa...
# 4    {'Chris Pratt': 'Peter Quill / Star-Lord', 'Zo...
# 5    {'Micah Abbey': 'Donatello (voice)', 'Nicolas ...
# ..                                                 ...
# 382  {'Hugh Jackman': 'Logan / Wolverine', 'Liev Sc...
# 539  {'James McAvoy': 'Charles Xavier / Professor X...
# 577  {'Patrick Stewart': 'Charles Xavier / Professo...
# 610  {'Hugh Jackman': 'Logan / Wolverine', 'Patrick...
# 713                       {'Alyy Khan': 'Young Mangu'}
#
#                                              direction  \
# 0                                  [Ángel Manuel Soto]
# 1    [Joaquim Dos Santos, Justin K. Thompson, Kemp ...
# 2                                    [Andy Muschietti]
# 4                                         [James Gunn]
# 5                                          [Jeff Rowe]
# ..                                                 ...
# 382                                       [Gavin Hood]
# 539                                   [Matthew Vaughn]
# 577                                     [Bryan Singer]
# 610                                     [Bryan Singer]
# 713                            [Sharmeen Obaid-Chinoy]
#
#                                   production_companies  movie_budget  \
# 0    [Warner Bros. Pictures, The Safran Company, DC...     120000000
# 1    [Columbia Pictures, Sony Pictures Animation, L...     100000000
# 2    [Warner Bros. Pictures, Double Dream, The Disc...     300000000
# 4            [Marvel Studios, Kevin Feige Productions]     250000000
# 5    [Paramount, Nickelodeon Movies, Point Grey Pic...      75000000
# ..                                                 ...           ...
# 382  [The Donners' Company, Seed Productions, 20th ...     150000000
# 539  [The Donners' Company, Bad Hat Harry Productio...     160000000
# 577  [The Donners' Company, Bad Hat Harry Productio...      75000000
# 610  [The Donners' Company, Bad Hat Harry Productio...     110000000
# 713           [Waadi Animations, ARY Films, SOC Films]        143149
#
#      movie_revenue
# 0        128563796
# 1        683241751
# 2        268375616
# 4        845430302
# 5        180000000
# ..             ...
# 382      373062864
# 539      353624124
# 577      296339527
# 610      407711549
# 713         645135
#
# [167 rows x 7 columns]

# %%
df.to_csv("../data/processed/movie_stats/movie_stats.csv")

# %%
movie_list_filtered = df["movie_name"].to_list()
for i in range(len(movie_list_filtered)):
    movie_list_filtered[i] = movie_list_filtered[i].lower()
    movie_list_filtered[i] = movie_list_filtered[i].replace(":", "")
    movie_list_filtered[i] = movie_list_filtered[i].replace(" ", "-")

# %%
from json import loads, dumps
json_object = dumps(movie_list_filtered, indent=4)

# %%
with open("../data/raw/movie_stats/superhero_list.json", "w") as outfile:
    outfile.write(json_object)
